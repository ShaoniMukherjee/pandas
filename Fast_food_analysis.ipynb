# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patheffects as path_effects
import seaborn as sns

# %%
nutrition_df = pd.read_csv('fastfood.csv')

# %%
nutrition_df.shape
# Out:
# (515, 17)

# %%
nutrition_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 515 entries, 0 to 514
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   restaurant   515 non-null    object
#  1   item         515 non-null    object
#  2   calories     515 non-null    int64
#  3   cal_fat      515 non-null    int64
#  4   total_fat    515 non-null    int64
#  5   sat_fat      515 non-null    float64
#  6   trans_fat    515 non-null    float64
#  7   cholesterol  515 non-null    int64
#  8   sodium       515 non-null    int64
#  9   total_carb   515 non-null    int64
#  10  fiber        503 non-null    float64
#  11  sugar        515 non-null    int64
#  12  protein      514 non-null    float64
#  13  vit_a        301 non-null    float64
#  14  vit_c        305 non-null    float64
#  15  calcium      305 non-null    float64
#  16  salad        515 non-null    object
# dtypes: float64(7), int64(7), object(3)
# memory usage: 68.5+ KB

# %%
nutrition_df.head()
# Out:
#   restaurant                                       item  calories  cal_fat  \
# 0  Mcdonalds           Artisan Grilled Chicken Sandwich       380       60
# 1  Mcdonalds             Single Bacon Smokehouse Burger       840      410
# 2  Mcdonalds             Double Bacon Smokehouse Burger      1130      600
# 3  Mcdonalds  Grilled Bacon Smokehouse Chicken Sandwich       750      280
# 4  Mcdonalds   Crispy Bacon Smokehouse Chicken Sandwich       920      410
#
#    total_fat  sat_fat  trans_fat  cholesterol  sodium  total_carb  fiber  \
# 0          7      2.0        0.0           95    1110          44    3.0
# 1         45     17.0        1.5          130    1580          62    2.0
# 2         67     27.0        3.0          220    1920          63    3.0
# 3         31     10.0        0.5          155    1940          62    2.0
# 4         45     12.0        0.5          120    1980          81    4.0
#
#    sugar  protein  vit_a  vit_c  calcium  salad
# ...

# %%
#removing unnecessary columns
nutrition_df.drop(['salad'], axis = 1, inplace=True)

# %%
nutrition_df.describe()
# Out:
#           calories      cal_fat   total_fat     sat_fat   trans_fat  \
# count   515.000000   515.000000  515.000000  515.000000  515.000000
# mean    530.912621   238.813592   26.590291    8.153398    0.465049
# std     282.436147   166.407510   18.411876    6.418811    0.839644
# min      20.000000     0.000000    0.000000    0.000000    0.000000
# 25%     330.000000   120.000000   14.000000    4.000000    0.000000
# 50%     490.000000   210.000000   23.000000    7.000000    0.000000
# 75%     690.000000   310.000000   35.000000   11.000000    1.000000
# max    2430.000000  1270.000000  141.000000   47.000000    8.000000
#
#        cholesterol       sodium  total_carb       fiber       sugar  \
# count   515.000000   515.000000  515.000000  503.000000  515.000000
# mean     72.456311  1246.737864   45.664078    4.137177    7.262136
# std      63.160406   689.954278   24.883342    3.037460    6.761301
# min       0.000000    15.000000    0.000000    0.000000    0.000000
# ...

# %%
nutrition_df['restaurant'].value_counts()
# Out:
# Taco Bell      115
# Subway          96
# Burger King     70
# Mcdonalds       57
# Arbys           55
# Sonic           53
# Dairy Queen     42
# Chick Fil-A     27
# Name: restaurant, dtype: int64

# %%
nutrition_df.isnull().sum()
# Out:
# restaurant       0
# item             0
# calories         0
# cal_fat          0
# total_fat        0
# sat_fat          0
# trans_fat        0
# cholesterol      0
# sodium           0
# total_carb       0
# fiber           12
# sugar            0
# protein          1
# vit_a          214
# vit_c          210
# calcium        210
# dtype: int64

# %%
nutrition_df['item'].nunique()
# Out:
# 505

# %%
#nutrition_df[nutrition_df['calories'] > 500]

# %%
#nutrition_df['item'].value_counts()

# %%
fig, axes = plt.subplots(2, 4, figsize=(16, 8))
 
fig.suptitle('Variation of Total fat and Calories across Fast food chains')

sns.scatterplot(ax=axes[0, 0], 
                data=nutrition_df[nutrition_df['restaurant']=='Mcdonalds'], y='total_fat', x='calories',hue='restaurant')
sns.scatterplot(ax=axes[0, 1], 
                data=nutrition_df[nutrition_df['restaurant']=='Subway'], y='total_fat', x='calories',hue='restaurant')
sns.scatterplot(ax=axes[0, 2], 
                data=nutrition_df[nutrition_df['restaurant']=='Sonic'], y='total_fat', x='calories',hue='restaurant')
sns.scatterplot(ax=axes[0, 3], 
                data=nutrition_df[nutrition_df['restaurant']=='Arbys'], y='total_fat', x='calories',hue='restaurant')
sns.scatterplot(ax=axes[1, 0], 
                data=nutrition_df[nutrition_df['restaurant']=='Chick Fil-A'], y='total_fat', x='calories',hue='restaurant')
sns.scatterplot(ax=axes[1, 1], 
                data=nutrition_df[nutrition_df['restaurant']=='Burger King'], y='total_fat', x='calories',hue='restaurant')
sns.scatterplot(ax=axes[1, 2], 
                data=nutrition_df[nutrition_df['restaurant']=='Dairy Queen'], y='total_fat', x='calories',hue='restaurant')
sns.scatterplot(ax=axes[1, 3], 
                data=nutrition_df[nutrition_df['restaurant']=='Taco Bell'], y='total_fat', x='calories',hue='restaurant')
# Out:
# <AxesSubplot:xlabel='calories', ylabel='total_fat'>

# %%
for i in nutrition_df['restaurant'].unique():
    
    data = nutrition_df[nutrition_df['restaurant'] == i]
    sns.scatterplot(x="total_fat",
                    y="calories",
                    data=data)

# %%
nutrition_df.columns
# Out:
# Index(['restaurant', 'item', 'calories', 'cal_fat', 'total_fat', 'sat_fat',
#        'trans_fat', 'cholesterol', 'sodium', 'total_carb', 'fiber', 'sugar',
#        'protein', 'vit_a', 'vit_c', 'calcium'],
#       dtype='object')

# %%
nutrition_df.select_dtypes('object')
# Out:
#     restaurant                                       item
# 0    Mcdonalds           Artisan Grilled Chicken Sandwich
# 1    Mcdonalds             Single Bacon Smokehouse Burger
# 2    Mcdonalds             Double Bacon Smokehouse Burger
# 3    Mcdonalds  Grilled Bacon Smokehouse Chicken Sandwich
# 4    Mcdonalds   Crispy Bacon Smokehouse Chicken Sandwich
# ..         ...                                        ...
# 510  Taco Bell             Spicy Triple Double Crunchwrap
# 511  Taco Bell                Express Taco Salad w/ Chips
# 512  Taco Bell                     Fiesta Taco Salad-Beef
# 513  Taco Bell                  Fiesta Taco Salad-Chicken
# 514  Taco Bell                    Fiesta Taco Salad-Steak
#
# [515 rows x 2 columns]

# %%
def nans1(df):
    nan_count = df.isna().sum().sort_values(ascending= False)
    nan_perc= (nan_count / df.shape[0]) * 100
    nans = pd.concat([nan_count,nan_perc],axis = 1).reset_index()
    nans.rename(columns = {0 : 'NaN Count' , 1:'Nan Perc'},inplace= True)
    return nans

# %%
nans1(nutrition_df)
# Out:
#           index  NaN Count   Nan Perc
# 0         vit_a        214  41.553398
# 1         vit_c        210  40.776699
# 2       calcium        210  40.776699
# 3         fiber         12   2.330097
# 4       protein          1   0.194175
# 5    restaurant          0   0.000000
# 6          item          0   0.000000
# 7      calories          0   0.000000
# 8       cal_fat          0   0.000000
# 9     total_fat          0   0.000000
# 10      sat_fat          0   0.000000
# 11    trans_fat          0   0.000000
# 12  cholesterol          0   0.000000
# 13       sodium          0   0.000000
# 14   total_carb          0   0.000000
# 15        sugar          0   0.000000

# %%
#nutrition_df[nutrition_df['vit_c'].isnull()]

# %%
# substituting the values of nans in vita a, vita c, calcium as 0
nutrition_df.fillna(value = {'vit_a' : 0,'vit_c' : 0,'calcium' : 0},inplace=True)

# %%
#nutrition_df[nutrition_df['vit_a'] == 0]

# %%
nutrition_df.fillna(value = {'protein' : nutrition_df['protein'].mean(),
                  'fiber' : nutrition_df['fiber'].mean()},inplace=True)

# %%
def determine_strength(r):
    
    if r == -1:
        return 'Perfect negative'
    elif r > -1 and r < -0.5:
        return 'Strong Negative'
    elif r == -0.5:
        return 'Medium Negative'
    elif r > -0.5 and r < 0 :
        return 'Weak Negative'
    elif r == 0:
        return 'No Correaltion'
    elif r > 0 and r < 0.5:
        return 'Weak Positive'
    elif r == 0.5:
        return 'Medium Positive'
    elif r > 0.5 and r < 1:
        return 'Strong Positive'
    elif r == 1:
        return 'Perfect Positive'

# %%
def group_agg(by_out):
    return nutrition_df.groupby('restaurant')[[by_out]].aggregate(np.mean).sort_values(by = by_out)

def group_agg_item(by_out):
    return nutrition_df.groupby('item')[[by_out]].aggregate(np.mean).sort_values(by = by_out)

# %%
##inspiration

##https://www.kaggle.com/code/mohmoataz/eda-fast-food#Full--Function-in-kaggle-Notebook-(Hide-Because-of-the-large-code-size)

# %%
nutrition_df.head()
# Out:
#   restaurant                                       item  calories  cal_fat  \
# 0  Mcdonalds           Artisan Grilled Chicken Sandwich       380       60
# 1  Mcdonalds             Single Bacon Smokehouse Burger       840      410
# 2  Mcdonalds             Double Bacon Smokehouse Burger      1130      600
# 3  Mcdonalds  Grilled Bacon Smokehouse Chicken Sandwich       750      280
# 4  Mcdonalds   Crispy Bacon Smokehouse Chicken Sandwich       920      410
#
#    total_fat  sat_fat  trans_fat  cholesterol  sodium  total_carb  fiber  \
# 0          7      2.0        0.0           95    1110          44    3.0
# 1         45     17.0        1.5          130    1580          62    2.0
# 2         67     27.0        3.0          220    1920          63    3.0
# 3         31     10.0        0.5          155    1940          62    2.0
# 4         45     12.0        0.5          120    1980          81    4.0
#
#    sugar  protein  vit_a  vit_c  calcium
# ...

# %%
plt.figure(figsize=(18,10))
sns.heatmap(nutrition_df.drop(['restaurant','item'],axis = 1).corr(),fmt = '.2f' ,annot=True, cmap = "crest")
plt.title('The Correlation between Nutrition')
plt.tight_layout()
plt.show()

# %%
plt.pie(nutrition_df['restaurant'].value_counts().values , 
        labels =nutrition_df['restaurant'].value_counts().index 
        , shadow = True , autopct= '%1.1f%%', wedgeprops= {'edgecolor' : 'black'} )
plt.grid()
plt.title('The popular eateries')
plt.tight_layout()
plt.show()
#plt.figure(figsize=(18,10))
